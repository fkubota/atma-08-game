# %% [markdown]
# # Overview
# - Name特徴量から情報を抽出して特徴量としたい
# - nb015の結果(cv: 1.00127)

# %% [markdown]
# # Const

# %%
NB = '016'

PATH_TRAIN = './../data/official/train.csv'
PATH_TEST = './../data/official/test.csv'
PATH_SAMPLE_SUBMITTION = './../data/official/atmaCup8_sample-submission.csv'
SAVE_DIR = f'../data/output_nb/nb{NB}/'

feat_train_only = ['JP_Sales', 'Global_Sales', 'NA_Sales', 'Other_Sales', 'EU_Sales']
feat_common = ['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher',
           'Critic_Score', 'Critic_Count', 'User_Score', 'User_Count', 'Developer',
           'Rating']
feat_string = ['Platform', 'Genre', 'Publisher', 'Developer', 'Rating']
feat_cat = ['Platform', 'Genre', 'Rating']
feat_num = ['Year_of_Release', 'Critic_Score', 'Critic_Count', 'User_Score', 'User_Count']
use_col = [
    'Platform',
    'Year_of_Release',
    'Genre',
    'Critic_Score',
    'Critic_Count',
    'User_Score',
    'User_Count',
    'Rating'
    ]

# %%
config_str = """
globals:
  seed: 2020
  show_log: True

feature:
    use_col: [
        'Platform',
        'Year_of_Release',
        'Genre',
        'Critic_Score',
        'Critic_Count',
        'User_Score',
        'User_Count',
        'Rating'
        ]

split:
  name: KFold
  params:
    n_splits: 5
    random_state: 2020
    shuffle: True

model:
    model_params:
        objective: 'regression'
        metric: 'rmse'
        n_estimators: 800
        max_depth: 131
        subsample: 0.6
        colsample_bytree: 0.9
        learning_rate: 0.022862256818781214
        reg_alpha: 1.0
        reg_lambda: 6.0
        min_child_samples: 10
    
    train_params:
        categorical_feature: ['Platform', 'Genre', 'Rating']
        verbose: -1
        early_stopping_rounds: 100
"""

# %% [markdown]
# # Import everything I need :)

# %%
import os
import time
import yaml
import types
import builtins
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from fastprogress import progress_bar

from lightgbm import LGBMRegressor 

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import train_test_split, KFold

import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %% [markdown]
# # My function

# %%
# noglobal

def imports():
    for name, val in globals().items():
        # module imports
        if isinstance(val, types.ModuleType):
            yield name, val

            # functions / callables
        if hasattr(val, '__call__'):
            yield name, val


def noglobal(f):
    '''
    ref: https://gist.github.com/raven38/4e4c3c7a179283c441f575d6e375510c
    '''
    return types.FunctionType(f.__code__,
                              dict(imports()),
                              f.__name__,
                              f.__defaults__,
                              f.__closure__
                              )

# %%
@noglobal
def metric(y_true, y_pred):
    return mean_squared_log_error(y_true, y_pred) ** .5

@noglobal
def preprocess_User_Score(df):
    '''
    - tbdをnanにする
    - stringをfloatにする
    '''
    mask = df.User_Score.values == 'tbd'
    df.User_Score[mask] = np.nan
    df.User_Score = df.User_Score.values.astype(float)
    return df

@noglobal
def string_encode(df_trn, df_te, cols):
    '''
    - np.nanがあれば、'nan'に置き換える
    - label encodingする
    '''
    df = pd.concat([df_trn, df_te], axis=0).copy()
    df[cols] = df[cols].replace(np.nan, 'nan')
    df_trn[cols] = df_trn[cols].replace(np.nan, 'nan')
    df_te[cols] = df_te[cols].replace(np.nan, 'nan')
    for col in cols:
        le = LabelEncoder()
        le.fit(df[col])
        df_trn[col] = le.transform(df_trn[col])
        df_te[col] = le.transform(df_te[col])
    return df_trn, df_te

@noglobal
def df_preprocessing(df_trn, df_te, string_cols):
    df_trn = preprocess_User_Score(df_trn)
    df_te = preprocess_User_Score(df_te)
    df_trn, df_te = string_encode(df_trn, df_te, string_cols)
    return df_trn, df_te

# %%
@noglobal
def run_fold_lgbm(_X_trn, _y_trn, _X_val, _y_val, _X_te, model_config, show_log=True):
    model_params = model_config['model_params']
    train_params = model_config['train_params']
    
    # train
    model = LGBMRegressor(**model_params)
    model.fit(_X_trn, _y_trn.values[:, 0],
              eval_set=[(_X_trn, _y_trn), (_X_val, _y_val)],
              **train_params
             )
    
    # predict
    y_trn_pred = model.predict(_X_trn)
    y_val_pred = model.predict(_X_val)
    _y_test_pred = model.predict(_X_te)
    
    # postprocessiing
    y_trn_pred[y_trn_pred <= 1] = 1
    y_val_pred[y_val_pred <= 1] = 1
    y_trn_pred = np.expm1(y_trn_pred)  # exp を適用して 1 を引く
    y_val_pred = np.expm1(y_val_pred)  # exp を適用して 1 を引く
    _y_test_pred = np.expm1(_y_test_pred)  # exp を適用して 1 を引く
    
    if show_log:
        print(show_log)
        print(f'score train: {metric(np.expm1(_y_trn), y_trn_pred):.5f}')
        print(f'score valid: {metric(np.expm1(_y_val), y_val_pred):.5f}')
        print('')
    
    return y_trn_pred, y_val_pred, _y_test_pred

@noglobal
def run_lgbm(X, y, X_te, splitter, config):
    show_log = config['globals']['show_log']
    model_config = config['model']

    oof = np.zeros(len(X))
    y_test_pred = np.zeros(len(X_te))
    for fold_i, (idx_trn, idx_val) in enumerate(splitter.split(X)):
        if show_log:
            print(f'::Fold {fold_i+1}/{splitter.n_splits} start at {time.ctime()}::')
        X_trn, X_val = X.iloc[idx_trn, :], X.iloc[idx_val, :]
        y_trn, y_val = y.iloc[idx_trn], y.iloc[idx_val]
        X_trn = pd.DataFrame(X_trn, columns=X.columns)
        X_val = pd.DataFrame(X_val, columns=X.columns)

        # train
        y_trn_pred, y_val_pred, _y_test_pred = run_fold_lgbm(X_trn, y_trn, X_val, y_val, 
                                                             X_te, model_config, 
                                                             show_log=show_log)

        # result
        oof[idx_val] = y_val_pred
        y_test_pred += _y_test_pred / splitter.n_splits


    y_test_pred[y_test_pred <= 1] = 1
    return oof, y_test_pred

# %% [markdown]
# # Preparation

# %% [markdown]
# set

# %%
if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

config = yaml.safe_load(config_str)

# %% [markdown]
# <br>
#
# load dataset

# %%
train = pd.read_csv(PATH_TRAIN)
test = pd.read_csv(PATH_TEST)
ss = pd.read_csv(PATH_SAMPLE_SUBMITTION)

# %% [markdown]
# <br>
#
# preprocess

# %%
train, test = df_preprocessing(train, test, feat_string)

# %%
X = train[use_col].copy()
y = train[['Global_Sales']].copy()
X_te = test[use_col].copy()

# %%
X
# Out:
#       Platform  Year_of_Release  Genre  Critic_Score  Critic_Count  \
# 0           26              NaN      0          74.0          17.0
# 1           26              NaN      0          78.0          22.0
# 2           19              NaN      0          73.0           5.0
# 3            0              NaN      0           NaN           NaN
# 4           26              NaN      0          76.0           8.0
# ...        ...              ...    ...           ...           ...
# 8354        13           2016.0     11          78.0          57.0
# 8355        13           2016.0     11           NaN           NaN
# 8356        20           2017.0      0           NaN           NaN
# 8357        18           2017.0      7           NaN           NaN
# 8358        20           2017.0      7           NaN           NaN
#
#       User_Score  User_Count  Rating
# 0            7.9        22.0       2
# 1            6.6        28.0       2
# 2            7.4        10.0       2
# 3            NaN         NaN       8
# 4            7.8        13.0       2
# ...          ...         ...     ...
# 8354         8.0       569.0       8
# 8355         NaN         NaN       8
# 8356         NaN         NaN       8
# 8357         NaN         NaN       8
# 8358         NaN         NaN       8
#
# [8359 rows x 8 columns]

# %%
# RMSLE を RMSEとしいて解く
y = np.log1p(y)  # 1 を足してlog を適用

# %% [markdown]
# # EDA

# %% [markdown]
# <br>
#
# textを小文字にして1行に

# %%
text_line = ' '.join(train.Name.str.lower().values)
text_line[:600]
# Out:
# "lego batman: the videogame lego indiana jones: the original adventures lego batman: the videogame combat lego harry potter: years 5-7 lego harry potter: years 5-7 yakuza 4 lego harry potter: years 5-7 the lord of the rings: war in the north the lord of the rings: war in the north the chronicles of narnia: the lion, the witch and the wardrobe lego harry potter: years 5-7 the golden compass circus atari maze craze: a game of cops 'n robbers robert ludlum's the bourne conspiracy lego harry potter: years 5-7 robert ludlum's the bourne conspiracy the golden compass tomb raider (2013) slot machine t"

# %% [markdown]
# <br>
#
# 上位100個を見て、使えそうなワードを抜き出す

# %%
value_counts = pd.Series(text_line.split(None)).value_counts()
for idx in range(100):
    print(f'{value_counts.index[idx]} \t {value_counts[idx]}')
# Out:
# the 	 1505
# of 	 867
# 2 	 428
# no 	 400
# & 	 210
# 3 	 207
# super 	 193
# world 	 172
# star 	 159
# 2: 	 157
# lego 	 139
# - 	 138
# to 	 137
# and 	 136
# game 	 124
# dragon 	 122
# ds 	 115
# mario 	 110
# final 	 105
# ii 	 103
# nba 	 94
# in 	 93
# fantasy 	 92
# warriors 	 89
# 4 	 89
# 3: 	 87
# vs. 	 86
# collection 	 86
# a 	 81
# man 	 77
# battle 	 76
# sonic 	 76
# wars 	 72
# sales) 	 72
# heroes 	 72
# quest 	 70
# portable 	 69
# shin 	 67
# challenge 	 67
# force 	 67
# mega 	 67
# wwe 	 67
# legend 	 67
# party 	 66
# edition 	 64
# disney 	 64
# ultimate 	 64
# king 	 63
# wars: 	 61
# baseball 	 61
# pro 	 60
# rock 	 60
# racing 	 60
# series 	 58
# championship 	 58
# samurai 	 57
# disney's 	 56
# games 	 56
# war 	 56
# monster 	 55
# resident 	 55
# band 	 51
# ni 	 51
# mlb 	 50
# dead 	 50
# x 	 49
# adventure 	 49
# dynasty 	 49
# grand 	 49
# pack 	 48
# (jp 	 48
# league 	 48
# dark 	 48
# soccer 	 47
# evil 	 47
# de 	 46
# fighter 	 45
# new 	 45
# 5 	 44
# ninja 	 43
# / 	 43
# iii 	 43
# ball 	 42
# club 	 42
# football 	 42
# video 	 41
# tour 	 40
# shadow 	 40
# marvel 	 39
# legends 	 39
# vol. 	 39
# tennis 	 39
# ii: 	 39
# power 	 39
# major 	 39
# taisen 	 39
# chronicles 	 39
# big 	 38
# virtua 	 37
# nfl 	 37

# %%
texts = [
    'super', 'world', 'star', 'lego', 'game', 'dragon', 'ds', 'mario',
    'final', 'fantasy',  'vs.', 'collection', 'man', 'sonic', 'battle',
    'quest', 'portable', 'shin', 'disney', 'baseball', 'soccer'
    ]

# %%
train_has_word = pd.DataFrame()
for text in progress_bar(texts):
    bools = []
    for name in train.Name.str.lower().values:
        words = np.array(name.split(None))
        bools.append(any(words == text))
    train_has_word[f'Name_has_{text}'] = bools
    
test_has_word = pd.DataFrame()
for text in progress_bar(texts):
    bools = []
    for name in test.Name.str.lower().values:
        words = np.array(str(name).split(None))
        bools.append(any(words == text))
    test_has_word[f'Name_has_{text}'] = bools
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21' class='' max='21' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21/21 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21' class='' max='21' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21/21 00:00<00:00]
#     </div>

# %%
train_has_word.head()
# Out:
#    Name_has_super  Name_has_world  Name_has_star  Name_has_lego  \
# 0           False           False          False           True
# 1           False           False          False           True
# 2           False           False          False           True
# 3           False           False          False          False
# 4           False           False          False           True
#
#    Name_has_game  Name_has_dragon  Name_has_ds  Name_has_mario  \
# 0          False            False        False           False
# 1          False            False        False           False
# 2          False            False        False           False
# 3          False            False        False           False
# 4          False            False        False           False
#
#    Name_has_final  Name_has_fantasy  ...  Name_has_collection  Name_has_man  \
# 0           False             False  ...                False         False
# 1           False             False  ...                False         False
# 2           False             False  ...                False         False
# 3           False             False  ...                False         False
# 4           False             False  ...                False         False
#
#    Name_has_sonic  Name_has_battle  Name_has_quest  Name_has_portable  \
# 0           False            False           False              False
# 1           False            False           False              False
# 2           False            False           False              False
# 3           False            False           False              False
# 4           False            False           False              False
#
#    Name_has_shin  Name_has_disney  Name_has_baseball  Name_has_soccer
# 0          False            False              False            False
# 1          False            False              False            False
# 2          False            False              False            False
# 3          False            False              False            False
# 4          False            False              False            False
#
# [5 rows x 21 columns]

# %% [markdown]
# ---> 新しい特徴量作った

# %% [markdown]
# # Experiments
# - 新しい特徴量を一つづつ加えながらスコアの変動を見る
# - nb015の結果(base_cv = 1.00127)と比較する

# %%
base_cv = 1.00127

# %%
# %%time

new_scores = []
splitter = KFold(**config['split']['params'])
for col in train_has_word.columns:
    X_new = X.copy()
    X_te_new = X_te.copy()
    X_new[col] = train_has_word[col].values
    X_te_new[col] = test_has_word[col].values
    
    oof, y_test_pred = run_lgbm(X_new, y, X_te_new, splitter, config)
    new_cv = metric(np.expm1(y), oof)
    new_scores.append(new_cv)
# Out:
# ::Fold 1/5 start at Mon Dec  7 23:12:00 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [405]	valid_0's rmse: 0.888219	valid_1's rmse: 0.991295
# True
# score train: 0.88822
# score valid: 0.99129
#
# ::Fold 2/5 start at Mon Dec  7 23:12:00 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [660]	valid_0's rmse: 0.84741	valid_1's rmse: 1.01674
# True
# score train: 0.84742
# score valid: 1.01674
#
# ::Fold 3/5 start at Mon Dec  7 23:12:01 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [675]	valid_0's rmse: 0.852182	valid_1's rmse: 0.997567
# True
# score train: 0.85220
# score valid: 0.99756
#
# ::Fold 4/5 start at Mon Dec  7 23:12:02 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [467]	valid_0's rmse: 0.884161	valid_1's rmse: 0.969457
# True
# score train: 0.88416
# score valid: 0.96946
#
# ::Fold 5/5 start at Mon Dec  7 23:12:03 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [636]	valid_0's rmse: 0.848387	valid_1's rmse: 1.01204
# True
# score train: 0.84840
# score valid: 1.01204
#
# ::Fold 1/5 start at Mon Dec  7 23:12:04 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [436]	valid_0's rmse: 0.889011	valid_1's rmse: 0.995165
# True
# score train: 0.88901
# score valid: 0.99511
#
# ::Fold 2/5 start at Mon Dec  7 23:12:05 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.837769	valid_1's rmse: 1.02417
# True
# score train: 0.83779
# score valid: 1.02417
#
# ::Fold 3/5 start at Mon Dec  7 23:12:06 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [626]	valid_0's rmse: 0.862576	valid_1's rmse: 1.00258
# True
# score train: 0.86259
# score valid: 1.00258
#
# ::Fold 4/5 start at Mon Dec  7 23:12:07 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [363]	valid_0's rmse: 0.905789	valid_1's rmse: 0.969837
# True
# score train: 0.90579
# score valid: 0.96984
#
# ::Fold 5/5 start at Mon Dec  7 23:12:07 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [488]	valid_0's rmse: 0.871982	valid_1's rmse: 1.01649
# True
# score train: 0.87199
# score valid: 1.01649
#
# ::Fold 1/5 start at Mon Dec  7 23:12:08 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [406]	valid_0's rmse: 0.892532	valid_1's rmse: 0.994159
# True
# score train: 0.89253
# score valid: 0.99416
#
# ::Fold 2/5 start at Mon Dec  7 23:12:09 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.838067	valid_1's rmse: 1.02272
# True
# score train: 0.83809
# score valid: 1.02272
#
# ::Fold 3/5 start at Mon Dec  7 23:12:10 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [688]	valid_0's rmse: 0.854236	valid_1's rmse: 1.00311
# True
# score train: 0.85426
# score valid: 1.00311
#
# ::Fold 4/5 start at Mon Dec  7 23:12:10 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [506]	valid_0's rmse: 0.88298	valid_1's rmse: 0.970483
# True
# score train: 0.88298
# score valid: 0.97048
#
# ::Fold 5/5 start at Mon Dec  7 23:12:11 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [489]	valid_0's rmse: 0.870253	valid_1's rmse: 1.01405
# True
# score train: 0.87026
# score valid: 1.01405
#
# ::Fold 1/5 start at Mon Dec  7 23:12:12 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [445]	valid_0's rmse: 0.885324	valid_1's rmse: 0.993317
# True
# score train: 0.88532
# score valid: 0.99328
#
# ::Fold 2/5 start at Mon Dec  7 23:12:13 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [689]	valid_0's rmse: 0.849579	valid_1's rmse: 1.01886
# True
# score train: 0.84959
# score valid: 1.01886
#
# ::Fold 3/5 start at Mon Dec  7 23:12:14 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [650]	valid_0's rmse: 0.857773	valid_1's rmse: 1.00266
# True
# score train: 0.85779
# score valid: 1.00266
#
# ::Fold 4/5 start at Mon Dec  7 23:12:15 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [343]	valid_0's rmse: 0.908093	valid_1's rmse: 0.967204
# True
# score train: 0.90809
# score valid: 0.96720
#
# ::Fold 5/5 start at Mon Dec  7 23:12:15 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [414]	valid_0's rmse: 0.882481	valid_1's rmse: 1.01204
# True
# score train: 0.88249
# score valid: 1.01204
#
# ::Fold 1/5 start at Mon Dec  7 23:12:16 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [433]	valid_0's rmse: 0.888455	valid_1's rmse: 0.995634
# True
# score train: 0.88845
# score valid: 0.99563
#
# ::Fold 2/5 start at Mon Dec  7 23:12:17 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [552]	valid_0's rmse: 0.865989	valid_1's rmse: 1.02508
# True
# score train: 0.86600
# score valid: 1.02507
#
# ::Fold 3/5 start at Mon Dec  7 23:12:17 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [651]	valid_0's rmse: 0.856287	valid_1's rmse: 1.00473
# True
# score train: 0.85631
# score valid: 1.00473
#
# ::Fold 4/5 start at Mon Dec  7 23:12:18 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [417]	valid_0's rmse: 0.896202	valid_1's rmse: 0.97028
# True
# score train: 0.89620
# score valid: 0.97028
#
# ::Fold 5/5 start at Mon Dec  7 23:12:19 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [484]	valid_0's rmse: 0.873697	valid_1's rmse: 1.01968
# True
# score train: 0.87371
# score valid: 1.01968
#
# ::Fold 1/5 start at Mon Dec  7 23:12:20 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [531]	valid_0's rmse: 0.874833	valid_1's rmse: 0.995203
# True
# score train: 0.87484
# score valid: 0.99513
#
# ::Fold 2/5 start at Mon Dec  7 23:12:21 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.837979	valid_1's rmse: 1.02503
# True
# score train: 0.83800
# score valid: 1.02503
#
# ::Fold 3/5 start at Mon Dec  7 23:12:22 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [556]	valid_0's rmse: 0.869716	valid_1's rmse: 1.00514
# True
# score train: 0.86973
# score valid: 1.00514
#
# ::Fold 4/5 start at Mon Dec  7 23:12:22 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [394]	valid_0's rmse: 0.89888	valid_1's rmse: 0.973069
# True
# score train: 0.89888
# score valid: 0.97307
#
# ::Fold 5/5 start at Mon Dec  7 23:12:23 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [436]	valid_0's rmse: 0.878553	valid_1's rmse: 1.0156
# True
# score train: 0.87856
# score valid: 1.01560
#
# ::Fold 1/5 start at Mon Dec  7 23:12:24 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [597]	valid_0's rmse: 0.86725	valid_1's rmse: 0.993169
# True
# score train: 0.86726
# score valid: 0.99314
#
# ::Fold 2/5 start at Mon Dec  7 23:12:25 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [569]	valid_0's rmse: 0.863993	valid_1's rmse: 1.02494
# True
# score train: 0.86400
# score valid: 1.02493
#
# ::Fold 3/5 start at Mon Dec  7 23:12:25 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [693]	valid_0's rmse: 0.853269	valid_1's rmse: 1.00107
# True
# score train: 0.85328
# score valid: 1.00107
#
# ::Fold 4/5 start at Mon Dec  7 23:12:26 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [412]	valid_0's rmse: 0.898698	valid_1's rmse: 0.970052
# True
# score train: 0.89870
# score valid: 0.97005
#
# ::Fold 5/5 start at Mon Dec  7 23:12:27 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [486]	valid_0's rmse: 0.869878	valid_1's rmse: 1.01778
# True
# score train: 0.86989
# score valid: 1.01778
#
# ::Fold 1/5 start at Mon Dec  7 23:12:28 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [464]	valid_0's rmse: 0.875734	valid_1's rmse: 0.984718
# True
# score train: 0.87574
# score valid: 0.98465
#
# ::Fold 2/5 start at Mon Dec  7 23:12:29 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [656]	valid_0's rmse: 0.843471	valid_1's rmse: 1.0124
# True
# score train: 0.84348
# score valid: 1.01241
#
# ::Fold 3/5 start at Mon Dec  7 23:12:29 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [698]	valid_0's rmse: 0.8425	valid_1's rmse: 0.984333
# True
# score train: 0.84253
# score valid: 0.98433
#
# ::Fold 4/5 start at Mon Dec  7 23:12:30 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [357]	valid_0's rmse: 0.895283	valid_1's rmse: 0.962947
# True
# score train: 0.89528
# score valid: 0.96295
#
# ::Fold 5/5 start at Mon Dec  7 23:12:31 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [553]	valid_0's rmse: 0.849731	valid_1's rmse: 1.00892
# True
# score train: 0.84975
# score valid: 1.00892
#
# ::Fold 1/5 start at Mon Dec  7 23:12:32 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [620]	valid_0's rmse: 0.864299	valid_1's rmse: 0.994364
# True
# score train: 0.86430
# score valid: 0.99430
#
# ::Fold 2/5 start at Mon Dec  7 23:12:33 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.840146	valid_1's rmse: 1.02519
# True
# score train: 0.84016
# score valid: 1.02517
#
# ::Fold 3/5 start at Mon Dec  7 23:12:34 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.841736	valid_1's rmse: 1.00282
# True
# score train: 0.84176
# score valid: 1.00282
#
# ::Fold 4/5 start at Mon Dec  7 23:12:35 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [502]	valid_0's rmse: 0.884477	valid_1's rmse: 0.97084
# True
# score train: 0.88448
# score valid: 0.97084
#
# ::Fold 5/5 start at Mon Dec  7 23:12:35 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [496]	valid_0's rmse: 0.871722	valid_1's rmse: 1.01702
# True
# score train: 0.87173
# score valid: 1.01702
#
# ::Fold 1/5 start at Mon Dec  7 23:12:36 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [456]	valid_0's rmse: 0.885348	valid_1's rmse: 0.996088
# True
# score train: 0.88535
# score valid: 0.99605
#
# ::Fold 2/5 start at Mon Dec  7 23:12:37 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.839266	valid_1's rmse: 1.02433
# True
# score train: 0.83928
# score valid: 1.02433
#
# ::Fold 3/5 start at Mon Dec  7 23:12:38 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [571]	valid_0's rmse: 0.86861	valid_1's rmse: 1.00513
# True
# score train: 0.86862
# score valid: 1.00513
#
# ::Fold 4/5 start at Mon Dec  7 23:12:39 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [638]	valid_0's rmse: 0.867234	valid_1's rmse: 0.970014
# True
# score train: 0.86724
# score valid: 0.97001
#
# ::Fold 5/5 start at Mon Dec  7 23:12:40 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [694]	valid_0's rmse: 0.84613	valid_1's rmse: 1.01557
# True
# score train: 0.84616
# score valid: 1.01557
#
# ::Fold 1/5 start at Mon Dec  7 23:12:41 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [447]	valid_0's rmse: 0.886655	valid_1's rmse: 0.9943
# True
# score train: 0.88666
# score valid: 0.99430
#
# ::Fold 2/5 start at Mon Dec  7 23:12:41 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [692]	valid_0's rmse: 0.848039	valid_1's rmse: 1.02299
# True
# score train: 0.84806
# score valid: 1.02300
#
# ::Fold 3/5 start at Mon Dec  7 23:12:42 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [553]	valid_0's rmse: 0.869482	valid_1's rmse: 1.00035
# True
# score train: 0.86949
# score valid: 1.00035
#
# ::Fold 4/5 start at Mon Dec  7 23:12:43 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [449]	valid_0's rmse: 0.890459	valid_1's rmse: 0.969203
# True
# score train: 0.89046
# score valid: 0.96920
#
# ::Fold 5/5 start at Mon Dec  7 23:12:44 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [651]	valid_0's rmse: 0.849711	valid_1's rmse: 1.01689
# True
# score train: 0.84972
# score valid: 1.01689
#
# ::Fold 1/5 start at Mon Dec  7 23:12:45 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [478]	valid_0's rmse: 0.883581	valid_1's rmse: 0.996207
# True
# score train: 0.88359
# score valid: 0.99613
#
# ::Fold 2/5 start at Mon Dec  7 23:12:45 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.838011	valid_1's rmse: 1.02503
# True
# score train: 0.83804
# score valid: 1.02502
#
# ::Fold 3/5 start at Mon Dec  7 23:12:46 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [607]	valid_0's rmse: 0.864673	valid_1's rmse: 1.00372
# True
# score train: 0.86468
# score valid: 1.00372
#
# ::Fold 4/5 start at Mon Dec  7 23:12:47 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [610]	valid_0's rmse: 0.869214	valid_1's rmse: 0.969766
# True
# score train: 0.86922
# score valid: 0.96976
#
# ::Fold 5/5 start at Mon Dec  7 23:12:48 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [461]	valid_0's rmse: 0.877613	valid_1's rmse: 1.01728
# True
# score train: 0.87762
# score valid: 1.01728
#
# ::Fold 1/5 start at Mon Dec  7 23:12:49 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [446]	valid_0's rmse: 0.88747	valid_1's rmse: 0.99536
# True
# score train: 0.88747
# score valid: 0.99534
#
# ::Fold 2/5 start at Mon Dec  7 23:12:50 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [692]	valid_0's rmse: 0.849021	valid_1's rmse: 1.02338
# True
# score train: 0.84903
# score valid: 1.02338
#
# ::Fold 3/5 start at Mon Dec  7 23:12:51 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [493]	valid_0's rmse: 0.878657	valid_1's rmse: 1.0046
# True
# score train: 0.87867
# score valid: 1.00460
#
# ::Fold 4/5 start at Mon Dec  7 23:12:51 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [411]	valid_0's rmse: 0.896986	valid_1's rmse: 0.971406
# True
# score train: 0.89698
# score valid: 0.97141
#
# ::Fold 5/5 start at Mon Dec  7 23:12:52 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [648]	valid_0's rmse: 0.851104	valid_1's rmse: 1.01654
# True
# score train: 0.85112
# score valid: 1.01654
#
# ::Fold 1/5 start at Mon Dec  7 23:12:53 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [487]	valid_0's rmse: 0.877697	valid_1's rmse: 0.991112
# True
# score train: 0.87771
# score valid: 0.99105
#
# ::Fold 2/5 start at Mon Dec  7 23:12:54 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [606]	valid_0's rmse: 0.855017	valid_1's rmse: 1.01737
# True
# score train: 0.85503
# score valid: 1.01737
#
# ::Fold 3/5 start at Mon Dec  7 23:12:54 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [472]	valid_0's rmse: 0.875721	valid_1's rmse: 1.00161
# True
# score train: 0.87572
# score valid: 1.00161
#
# ::Fold 4/5 start at Mon Dec  7 23:12:55 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [398]	valid_0's rmse: 0.896423	valid_1's rmse: 0.963521
# True
# score train: 0.89642
# score valid: 0.96352
#
# ::Fold 5/5 start at Mon Dec  7 23:12:56 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [415]	valid_0's rmse: 0.879606	valid_1's rmse: 1.01026
# True
# score train: 0.87961
# score valid: 1.01026
#
# ::Fold 1/5 start at Mon Dec  7 23:12:56 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [549]	valid_0's rmse: 0.874048	valid_1's rmse: 0.995505
# True
# score train: 0.87405
# score valid: 0.99546
#
# ::Fold 2/5 start at Mon Dec  7 23:12:57 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [571]	valid_0's rmse: 0.863874	valid_1's rmse: 1.02658
# True
# score train: 0.86388
# score valid: 1.02658
#
# ::Fold 3/5 start at Mon Dec  7 23:12:58 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [584]	valid_0's rmse: 0.865954	valid_1's rmse: 1.0041
# True
# score train: 0.86596
# score valid: 1.00410
#
# ::Fold 4/5 start at Mon Dec  7 23:12:59 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [618]	valid_0's rmse: 0.867813	valid_1's rmse: 0.972124
# True
# score train: 0.86782
# score valid: 0.97212
#
# ::Fold 5/5 start at Mon Dec  7 23:13:00 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [656]	valid_0's rmse: 0.852006	valid_1's rmse: 1.01561
# True
# score train: 0.85202
# score valid: 1.01561
#
# ::Fold 1/5 start at Mon Dec  7 23:13:01 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [557]	valid_0's rmse: 0.870979	valid_1's rmse: 0.991569
# True
# score train: 0.87098
# score valid: 0.99153
#
# ::Fold 2/5 start at Mon Dec  7 23:13:02 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [612]	valid_0's rmse: 0.858105	valid_1's rmse: 1.02452
# True
# score train: 0.85811
# score valid: 1.02453
#
# ::Fold 3/5 start at Mon Dec  7 23:13:02 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [562]	valid_0's rmse: 0.868302	valid_1's rmse: 1.00553
# True
# score train: 0.86831
# score valid: 1.00553
#
# ::Fold 4/5 start at Mon Dec  7 23:13:03 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [379]	valid_0's rmse: 0.90167	valid_1's rmse: 0.97099
# True
# score train: 0.90167
# score valid: 0.97099
#
# ::Fold 5/5 start at Mon Dec  7 23:13:04 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [535]	valid_0's rmse: 0.865225	valid_1's rmse: 1.01628
# True
# score train: 0.86523
# score valid: 1.01628
#
# ::Fold 1/5 start at Mon Dec  7 23:13:05 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [393]	valid_0's rmse: 0.895699	valid_1's rmse: 0.995185
# True
# score train: 0.89570
# score valid: 0.99517
#
# ::Fold 2/5 start at Mon Dec  7 23:13:05 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.83765	valid_1's rmse: 1.02639
# True
# score train: 0.83766
# score valid: 1.02640
#
# ::Fold 3/5 start at Mon Dec  7 23:13:06 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.843718	valid_1's rmse: 1.00121
# True
# score train: 0.84374
# score valid: 1.00121
#
# ::Fold 4/5 start at Mon Dec  7 23:13:07 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [583]	valid_0's rmse: 0.872964	valid_1's rmse: 0.970349
# True
# score train: 0.87297
# score valid: 0.97035
#
# ::Fold 5/5 start at Mon Dec  7 23:13:08 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [659]	valid_0's rmse: 0.851297	valid_1's rmse: 1.01556
# True
# score train: 0.85131
# score valid: 1.01554
#
# ::Fold 1/5 start at Mon Dec  7 23:13:09 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [472]	valid_0's rmse: 0.883634	valid_1's rmse: 0.995902
# True
# score train: 0.88364
# score valid: 0.99585
#
# ::Fold 2/5 start at Mon Dec  7 23:13:10 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.839001	valid_1's rmse: 1.02481
# True
# score train: 0.83902
# score valid: 1.02479
#
# ::Fold 3/5 start at Mon Dec  7 23:13:11 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [699]	valid_0's rmse: 0.852006	valid_1's rmse: 1.00433
# True
# score train: 0.85202
# score valid: 1.00433
#
# ::Fold 4/5 start at Mon Dec  7 23:13:12 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [427]	valid_0's rmse: 0.894471	valid_1's rmse: 0.968763
# True
# score train: 0.89447
# score valid: 0.96876
#
# ::Fold 5/5 start at Mon Dec  7 23:13:12 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [478]	valid_0's rmse: 0.873792	valid_1's rmse: 1.01795
# True
# score train: 0.87380
# score valid: 1.01795
#
# ::Fold 1/5 start at Mon Dec  7 23:13:13 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [479]	valid_0's rmse: 0.881689	valid_1's rmse: 0.994933
# True
# score train: 0.88169
# score valid: 0.99488
#
# ::Fold 2/5 start at Mon Dec  7 23:13:14 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [682]	valid_0's rmse: 0.849297	valid_1's rmse: 1.02112
# True
# score train: 0.84932
# score valid: 1.02111
#
# ::Fold 3/5 start at Mon Dec  7 23:13:15 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [589]	valid_0's rmse: 0.86589	valid_1's rmse: 1.00647
# True
# score train: 0.86590
# score valid: 1.00647
#
# ::Fold 4/5 start at Mon Dec  7 23:13:16 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [575]	valid_0's rmse: 0.873563	valid_1's rmse: 0.968077
# True
# score train: 0.87357
# score valid: 0.96808
#
# ::Fold 5/5 start at Mon Dec  7 23:13:17 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [467]	valid_0's rmse: 0.874629	valid_1's rmse: 1.0146
# True
# score train: 0.87464
# score valid: 1.01460
#
# ::Fold 1/5 start at Mon Dec  7 23:13:17 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [423]	valid_0's rmse: 0.890469	valid_1's rmse: 0.99641
# True
# score train: 0.89047
# score valid: 0.99638
#
# ::Fold 2/5 start at Mon Dec  7 23:13:18 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [623]	valid_0's rmse: 0.85922	valid_1's rmse: 1.02539
# True
# score train: 0.85923
# score valid: 1.02539
#
# ::Fold 3/5 start at Mon Dec  7 23:13:19 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [577]	valid_0's rmse: 0.866975	valid_1's rmse: 1.00513
# True
# score train: 0.86699
# score valid: 1.00513
#
# ::Fold 4/5 start at Mon Dec  7 23:13:20 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [614]	valid_0's rmse: 0.871195	valid_1's rmse: 0.969948
# True
# score train: 0.87120
# score valid: 0.96995
#
# ::Fold 5/5 start at Mon Dec  7 23:13:20 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [434]	valid_0's rmse: 0.880851	valid_1's rmse: 1.01853
# True
# score train: 0.88086
# score valid: 1.01853
#
# ::Fold 1/5 start at Mon Dec  7 23:13:21 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [423]	valid_0's rmse: 0.890469	valid_1's rmse: 0.99641
# True
# score train: 0.89047
# score valid: 0.99638
#
# ::Fold 2/5 start at Mon Dec  7 23:13:22 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.838603	valid_1's rmse: 1.0246
# True
# score train: 0.83863
# score valid: 1.02460
#
# ::Fold 3/5 start at Mon Dec  7 23:13:23 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.843312	valid_1's rmse: 1.00312
# True
# score train: 0.84334
# score valid: 1.00312
#
# ::Fold 4/5 start at Mon Dec  7 23:13:24 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.849572	valid_1's rmse: 0.971187
# True
# score train: 0.84958
# score valid: 0.97118
#
# ::Fold 5/5 start at Mon Dec  7 23:13:25 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [552]	valid_0's rmse: 0.863132	valid_1's rmse: 1.01866
# True
# score train: 0.86314
# score valid: 1.01866
#
# CPU times: user 16min 54s, sys: 7.41 s, total: 17min 1s
# Wall time: 1min 25s

# %%
df_result = pd.DataFrame()
df_result['Name_has'] = train_has_word.columns
df_result['new_cv'] = new_scores
df_result['base_cv - new_cv'] = base_cv - np.array(new_scores)

# %%
df_result.sort_values('base_cv - new_cv', ascending=False)
# Out:
#                Name_has    new_cv  base_cv - new_cv
# 7        Name_has_mario  0.990816          0.010454
# 13       Name_has_sonic  0.996938          0.004332
# 0        Name_has_super  0.997559          0.003711
# 3         Name_has_lego  0.998969          0.002301
# 10         Name_has_vs.  1.000925          0.000345
# 2         Name_has_star  1.001063          0.000207
# 18      Name_has_disney  1.001200          0.000070
# 6           Name_has_ds  1.001579         -0.000309
# 1        Name_has_world  1.001814         -0.000544
# 16    Name_has_portable  1.001914         -0.000644
# 15       Name_has_quest  1.001951         -0.000681
# 8        Name_has_final  1.002207         -0.000937
# 9      Name_has_fantasy  1.002394         -0.001124
# 12         Name_has_man  1.002417         -0.001147
# 17        Name_has_shin  1.002526         -0.001256
# 11  Name_has_collection  1.002563         -0.001293
# 14      Name_has_battle  1.002947         -0.001677
# 5       Name_has_dragon  1.002953         -0.001683
# 20      Name_has_soccer  1.002961         -0.001691
# 19    Name_has_baseball  1.003263         -0.001993
# 4         Name_has_game  1.003265         -0.001995

# %% [markdown]
# # 全部入れたら？

# %%
X_new = X.copy()
X_te_new = X_te.copy()
X_new = pd.concat([X, train_has_word], axis=1)
X_te_new = pd.concat([X_te, test_has_word], axis=1)

# %%
splitter = KFold(**config['split']['params'])
oof, y_test_pred = run_lgbm(X_new, y, X_te_new, splitter, config)
print(f'base_cv: {base_cv}')
print(f'oof score: {metric(np.expm1(y), oof):.5f}')
# Out:
# ::Fold 1/5 start at Mon Dec  7 23:20:28 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [660]	valid_0's rmse: 0.828361	valid_1's rmse: 0.965618
# True
# score train: 0.82838
# score valid: 0.96553
#
# ::Fold 2/5 start at Mon Dec  7 23:20:29 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.808563	valid_1's rmse: 0.985166
# True
# score train: 0.80858
# score valid: 0.98518
#
# ::Fold 3/5 start at Mon Dec  7 23:20:30 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.811791	valid_1's rmse: 0.973774
# True
# score train: 0.81181
# score valid: 0.97377
#
# ::Fold 4/5 start at Mon Dec  7 23:20:31 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [422]	valid_0's rmse: 0.869204	valid_1's rmse: 0.945342
# True
# score train: 0.86920
# score valid: 0.94534
#
# ::Fold 5/5 start at Mon Dec  7 23:20:32 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [409]	valid_0's rmse: 0.857972	valid_1's rmse: 0.991549
# True
# score train: 0.85798
# score valid: 0.99155
#
# base_cv: 1.00127
# oof score: 0.97241

# %% [markdown]
# ---> めちゃんこ上がってるやん

# %% [markdown]
# # よさそうなやつだけ入れてみる

# %%
good_words = [
    'Name_has_mario',
    'Name_has_sonic',
    'Name_has_super',
    'Name_has_lego',
    'Name_has_vs.',
    'Name_has_star',
    'Name_has_disney',
    ]

# %%
X_new = X.copy()
X_te_new = X_te.copy()
X_new = pd.concat([X, train_has_word[good_words]], axis=1)
X_te_new = pd.concat([X_te, test_has_word[good_words]], axis=1)

# %%
splitter = KFold(**config['split']['params'])
oof, y_test_pred = run_lgbm(X_new, y, X_te_new, splitter, config)
print(f'base_cv: {base_cv}')
print(f'oof score: {metric(np.expm1(y), oof):.5f}')
# Out:
# ::Fold 1/5 start at Mon Dec  7 23:25:15 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.820402	valid_1's rmse: 0.976033
# True
# score train: 0.82043
# score valid: 0.97595
#
# ::Fold 2/5 start at Mon Dec  7 23:25:16 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.814985	valid_1's rmse: 0.99292
# True
# score train: 0.81501
# score valid: 0.99292
#
# ::Fold 3/5 start at Mon Dec  7 23:25:17 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [564]	valid_0's rmse: 0.845801	valid_1's rmse: 0.97976
# True
# score train: 0.84581
# score valid: 0.97976
#
# ::Fold 4/5 start at Mon Dec  7 23:25:18 2020::
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's rmse: 0.826569	valid_1's rmse: 0.948647
# True
# score train: 0.82659
# score valid: 0.94865
#
# ::Fold 5/5 start at Mon Dec  7 23:25:19 2020::
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [676]	valid_0's rmse: 0.82577	valid_1's rmse: 0.993176
# True
# score train: 0.82580
# score valid: 0.99318
#
# base_cv: 1.00127
# oof score: 0.97822

# %% [markdown]
# # Save features

# %%
path = f'{SAVE_DIR}train_feature_name_has.csv'
train_has_word.to_csv(path, index=False, encoding='utf-8')
path
# Out:
# '../data/output_nb/nb016/train_feature_name_has.csv'

# %%
path = f'{SAVE_DIR}test_feature_name_has.csv'
test_has_word.to_csv(path, index=False, encoding='utf-8')
path
# Out:
# '../data/output_nb/nb016/test_feature_name_has.csv'

# %% [markdown]
# # 結論
# 全部入れたほうが良い
